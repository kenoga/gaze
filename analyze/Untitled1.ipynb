# %%
import os,sys
import numpy as np
from PIL import Image
import cv2
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../.."))

from dataset_utils.utils import imshow, gray, eqhist
from dataset_utils.utils import DS_ROOT

# %%
img = Image.open(os.path.join(DS_ROOT, "face", "0001", "0001_0_A_01_00000001.jpg")).convert('L')
# left, upper, right, lower
print(img.resize((100,100)).crop((50, 0, 100, 100)).size)
print(img.resize((100,100)).crop((0, 0, 50, 100)).size)
# Out:
# (50, 100)
# (50, 100)

# %%
imgn = np.array(img, dtype=np.int32)

# %%
imshow(imgn.)

# %%
img = cv2.imread(os.path.join(DS_ROOT, "face", "0001", "0001_0_A_01_00000001.jpg"))

# %%
imshow(gray(img))
