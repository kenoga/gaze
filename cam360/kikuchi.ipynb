# %%
% matplotlib inline
import numpy as np
from urllib.request import urlopen
from io import BytesIO
from skimage import io, draw
import codecs

# %%
path = './image/test1.mp4.0001.jpg'
img = io.imread(path)
io.imshow(img)
# Out:
# /Users/nogaken/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
# Out:
# (2880, 2880, 3)

# %%
H, W, _ = img.shape
hankei = 1400
rr, cc = draw.circle(H//2, W//2, hankei)
eimg = np.ones(img.shape, dtype=np.uint8) * 255
eimg[rr, cc, :] = img[rr, cc, :]
io.imshow(eimg)
io.imsave("testout.jpg", eimg)
# Out:
# /Users/nogaken/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
