# %%
import cv2
import matplotlib.pyplot as plt
import dataset_utils
from IPython.display import display, Image
import cv2
# %matplotlib inline

# %%
data = dataset_utils.get_image_paths('both_eyes')

# %%
heights = []
widths = []

num = len(data.keys())
for pid, paths in sorted(data.items()):
        color = ad
        for path in paths:
            img = cv2.imread(path)
            h, w, _ = img.shape
            
            heights.append(h)
            widths.append(w)

# %%
plt.plot(heights, widths, 'o')

# %%
h_ave = sum(heights) / float(len(heights))
w_ave = sum(widths) / float(len(widths))
print(h_ave, w_ave)
# Out:
# (46.79946468152733, 138.69598371739644)
